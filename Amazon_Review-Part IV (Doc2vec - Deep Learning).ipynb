# %%
import numpy as np 
import pandas as pd
#column width
pd.set_option('display.max_colwidth', 300)
pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', 100)
pd.set_option('display.width', 300)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier

import numpy as np 
import pandas as pd 
pd.set_option('display.max_colwidth', -1)
from time import time
import re
import string
import os
from pprint import pprint
import collections
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
import sklearn.externals 
import joblib
import gensim
import numpy as np 
import pandas as pd 
pd.set_option('display.max_colwidth', -1)
from time import time
import re
import string
import os
from pprint import pprint
import collections
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")
sns.set(font_scale=1.3)
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import classification_report
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
import sklearn.externals 
import joblib
import gensim
# Out:
# /Users/didemekinci/opt/anaconda3/envs/tf1/lib/python3.7/site-packages/ipykernel_launcher.py:23: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
# /Users/didemekinci/opt/anaconda3/envs/tf1/lib/python3.7/site-packages/gensim/similarities/__init__.py:15: UserWarning: The gensim.similarities.levenshtein submodule is disabled, because the optional Levenshtein package <https://pypi.org/project/python-Levenshtein/> is unavailable. Install Levenhstein (e.g. `pip install python-Levenshtein`) to suppress this warning.
#   warnings.warn(msg)
# /Users/didemekinci/opt/anaconda3/envs/tf1/lib/python3.7/site-packages/ipykernel_launcher.py:48: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
from time import strftime
from datetime import datetime
import pandas as pd 
import nltk
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
import re
import string
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, f1_score
from sklearn.svm import LinearSVC
from sklearn.metrics import classification_report
from nltk.corpus import stopwords
import seaborn as sns
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# pip install wordcloud

# %% [markdown]
# pip install vadersentiment

# %% [markdown]
# pip install gensim

# %% [markdown]
# pip install nltk

# %% [markdown]
# pip install plotly

# %% [markdown]
# pip install sklearn

# %% [markdown]
# pip install seaborn

# %% [markdown]
# pip install matplotlib

# %% [markdown]
# pip install --upgrade vaderSentiment

# %%
mypath="/Users/didemekinci/Desktop/Graduate Project/02_data/"
import pandas as pd
import glob
files = glob.glob("/Users/didemekinci/Desktop/Graduate Project/02_data/*.csv")
column_names=['marketplace',"customer_id","review_id","product_id","product_parent","product_title","product_category","star_rating","helpful_votes","total_votes","vine","verified_purchase","review_headline","review_body","review_date"]
df0=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000015.csv',sep="\t",names=column_names, low_memory=False)
df1=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000366.csv',sep="\t",names=column_names, low_memory=False)
df2=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000115.csv',sep="\t",names=column_names, low_memory=False)
df3=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000300.csv',sep="\t",names=column_names, low_memory=False)
df4=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000324.csv',sep="\t",names=column_names, low_memory=False)
df5=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000247.csv',sep="\t",names=column_names, low_memory=False)
df6=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000018.csv',sep="\t",names=column_names, low_memory=False)
df7=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000069.csv',sep="\t",names=column_names, low_memory=False)
df8=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000125.csv',sep="\t",names=column_names, low_memory=False)
df9=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000190.csv',sep="\t",names=column_names, low_memory=False)
df10=pd.read_csv('/Users/didemekinci/Desktop/Graduate Project/02_data/0000000268.csv',sep="\t",names=column_names, low_memory=False)
df = df0.append([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
df.index = np.arange(1, len(df)+1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1094466 entries, 1 to 1094466
# Data columns (total 15 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   marketplace        1094466 non-null  object
#  1   customer_id        1094466 non-null  int64
#  2   review_id          1094466 non-null  object
#  3   product_id         1094466 non-null  object
#  4   product_parent     1094466 non-null  int64
#  5   product_title      1094466 non-null  object
#  6   product_category   1094466 non-null  object
#  7   star_rating        1094464 non-null  object
#  8   helpful_votes      1094461 non-null  float64
#  9   total_votes        1094461 non-null  float64
#  10  vine               1094461 non-null  object
#  11  verified_purchase  1094461 non-null  object
#  12  review_headline    1094454 non-null  object
#  13  review_body        1094449 non-null  object
#  14  review_date        1094407 non-null  object
# ...

# %%
#CORRECTION OF COLUMNS AND TYPES
df = df.drop(df[(df.review_date == "1") | (df.review_date == "4") | (df.review_date == "2") | (df.review_date == "3") | (df.review_date == "5")| (df.review_date.isnull())].index)
df = df.drop(df[(df.star_rating == '2015-03-27')|(df.star_rating == "2015-04-17") | (df.star_rating == "2011-07-10") |  (df.star_rating.isnull())].index)
df['helpful_votes'] = df['helpful_votes'].fillna(0)
df['total_votes'] = df['total_votes'].fillna(0)
df= df.astype({"customer_id": int, "product_parent": int, "star_rating": int, "helpful_votes" : int, "total_votes":float, "review_body": str})
df['review_date']=pd.to_datetime(df['review_date'], format='%Y/%m/%d',errors ="ignore")

#adding review length and binary vectorize star rating by comment columns
df["review_len"]=[len(x) for x in df['review_body']]
df["comment"] = df['star_rating'].apply(lambda x: 1 if x>3 else 0)

# %% [markdown]
# # DATA CLEANSING

# %%
df = df.sample(frac=1).reset_index(drop=True) #shuffle
data=df[df['comment']==0][:187068]
data=data.append(df[df['comment']==1][:187068])
data = data.reset_index(drop=True)
display(data['comment'].value_counts())
df=data.copy()
# Out:
# 0    187068
# 1    187068
# Name: comment, dtype: int64

# %%
w = stopwords.words('english')
import nltk
from nltk.corpus import stopwords
nltk.download("stopwords")
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
from string import punctuation

def cleanText(text):
    #text = BeautifulSoup(text, "lxml",).text
    text = text.lower()

    text= text.replace('<br />',' ')
    text= text.replace('<br/>',' ')

    text = re.sub(r"won\'t", "will not", text)
    text = re.sub(r"can\'t", "can not", text)
    # general
    text = re.sub(r"n\'t", " not", text)
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'s", " is", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ll", " will", text)
    text = re.sub(r"\'t", " not", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"\'m", " am", text)
    text = re.sub(r'\|\|\| ', r'  ', text)
    text = re.sub(r'http\S+', r' <URL> ', text)
    text = re.sub(r"[-()\"#/@;:<>{}^`+=~|.!?,]", " ", text) 
    text = re.sub(r'[^a-zA-z.,!?/:;\"\'\s]', " ", text)
    text = re.sub(r'[^a-zA-z.,!?/:;\"\'\s]', " ", text)
    text = re.sub(r'[^\w]', ' ', text)
    text = re.sub("\s\s+", " ", text)
   # text=re.sub('(\\b[A-Ka-k] \\b|\\b [A-Ka-k]\\b)', '', text)
    return text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/didemekinci/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df['cleaned_review'] = df['review_body'].apply(cleanText)

# %%
def tokenize_sentence(s):
    tokens = nltk.tokenize.word_tokenize(s)
    # remove short words, they're probably not useful
    tokens = [t for t in tokens if len(t) > 2]
    # put words into base form
    #tokens = [t for t in tokens if t not in stopwords.words("english") + [""]]
    return tokens

# %%
df['tokenized_review'] = df['cleaned_review'].apply(tokenize_sentence)

# %% [raw]
# df["tokenized_string"] = df.tokenized_review.apply(lambda x: ' '.join([str(i) for i in x]))

# %%
from nltk.stem import WordNetLemmatizer

wordnet_lemmatizer = WordNetLemmatizer()

def lemmatize_sentence(s):
    
    tokens = [wordnet_lemmatizer.lemmatize(t, pos="v") for t in s]
    return tokens

# %%
df['lemmatized_review'] = df['tokenized_review'].apply(lemmatize_sentence)

# %%
df["lemmatized_string"] = df.lemmatized_review.apply(lambda x: ' '.join([str(i) for i in x]))

# %% [raw]
# stop = stopwords.words('english')
# df['lemmatized_string_wo_sw'] = df['lemmatized_string'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
# df["tokenized_string_wo_sw"] = df.tokenized_string.apply(lambda x: ''.join([str(i) for i in x]))

# %%
df_=df.copy()

# %% [markdown]
# # doc2vec - DeepLearning

# %%
import os
from tqdm import tqdm
import pandas as pd
import numpy as np
import re

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score
from sklearn.utils import shuffle
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB

from gensim.test.utils import get_tmpfile
from gensim.models.doc2vec import TaggedDocument

from gensim.models import Doc2Vec
from gensim import utils

# %% [raw]
# #80% train %20 test

# %%
x_train, x_validation, y_train, y_validation = train_test_split(df_.lemmatized_string, df_.comment, test_size=.2)

# %%
#using gensim for labelize 
def labelize_text(text,label):
    result = []
    prefix = label
    for i, t in zip(text.index, text):
        result.append(TaggedDocument(t.split(), [prefix + '_%s' % i]))
    return result
  
all_x = pd.concat([x_train,x_validation])

all_x_w2v = labelize_text(all_x, 'ALL')
x_train = labelize_text(x_train, 'TRAIN')
x_validation = labelize_text(x_validation, 'TEST')

# %%
#word2vex application for epoch 1 
from gensim.models.word2vec import Word2Vec
from tqdm import tqdm
from sklearn import utils
import numpy as np

model_w2v = Word2Vec(vector_size=200, min_count=10)
model_w2v.build_vocab([x.words for x in tqdm(all_x_w2v)])
model_w2v.train([x.words for x in tqdm(all_x_w2v)], total_examples=len(all_x_w2v), epochs=1)
# Out:
# ...
# 100%|██████████| 374136/374136 [00:00<00:00, 2540164.76it/s]
# (24106549, 31757466)

# %%
model_w2v.wv.most_similar('book',topn=5)
# Out:
# [('novel', 0.6045509576797485),
#  ('volume', 0.5228368639945984),
#  ('series', 0.4909791946411133),
#  ('novella', 0.4797981381416321),
#  ('cookbook', 0.4754897654056549)]

# %%
model_w2v.wv.most_similar('read',topn=5)
# Out:
# [('reread', 0.62032151222229),
#  ('finish', 0.6153013110160828),
#  ('pick', 0.5879789590835571),
#  ('buy', 0.5346026420593262),
#  ('purchase', 0.5237217545509338)]

# %%
model_w2v.wv.most_similar('author',topn=5)
# Out:
# [('writer', 0.641903281211853),
#  ('editors', 0.44533294439315796),
#  ('writers', 0.4449336528778076),
#  ('reviewers', 0.44097408652305603),
#  ('publisher', 0.4218423664569855)]

# %%
model_w2v.wv.most_similar('waste',topn=5)
# Out:
# [('wast', 0.7147767543792725),
#  ('spend', 0.617019534111023),
#  ('waisting', 0.5934469103813171),
#  ('invest', 0.5551362633705139),
#  ('spare', 0.5467881560325623)]

# %%
model_w2v.wv.most_similar('recommend',topn=5)
# Out:
# [('recomend', 0.8332269191741943),
#  ('reccomend', 0.8297561407089233),
#  ('reccommend', 0.7581509947776794),
#  ('recommed', 0.7052969932556152),
#  ('suggest', 0.6666118502616882)]

# %%
from sklearn.manifold import TSNE
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
vocab = list(model_w2v.wv.index_to_key)

# index vector values by corresponding vocab list

X = model_w2v.wv[vocab]

print("Total Number of Vocab:", len(X))
print()
print(X[0][:10])

# Visualize only 100 words.

tsne = TSNE(n_components = 2)
X_tsne = tsne.fit_transform(X[:100,:])
# Out:
# Total Number of Vocab: 39272
#
# [ 0.54960644 -0.63137597  0.8448627   0.8000926  -0.3239235   0.58005923
#   0.8718136   1.2539979   0.7733293   0.45346007]

# %%
#TNSE VIEW FOR WORD2VEC
fig = plt.figure()
fig.set_size_inches(30,20)

ax = fig.add_subplot(1,1,1)
ax.scatter(df['X'], df['Y'])

# Put the label on each point.
for word, pos in df.iterrows():
    ax.annotate(word, pos, fontsize = 30)
plt.show()

# %%
#tf-ıf transformation implement for vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(analyzer=lambda x: x, min_df=10)
matrix = vectorizer.fit_transform([x.words for x in all_x_w2v])
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))

def build_Word_Vector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0.
    for word in tokens:
        try:
            vec += model_w2v.wv[word].reshape((1, size)) * tfidf[word]
            count += 1.
        except KeyError: 
            
            continue
    if count != 0:
        vec /= count
    return vec

# %% [markdown]
# pip install keras --upgrade

# %%
from sklearn.preprocessing import scale
from tensorflow_core.python.keras.utils.data_utils import Sequence
from tensorflow.keras.utils import Sequence

import numpy as np
from tensorflow.python.keras.layers import LSTM, Dense
from tensorflow.python.keras.models import Sequential
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator

# %%
import tensorflow as tf

# %%
#TRAIN AND TEST FOR tqdm
train_vecs_w2v = np.concatenate([build_Word_Vector(z, 200) for z in tqdm(map(lambda x: x.words, x_train))])
train_vecs_w2v = scale(train_vecs_w2v)
val_vecs_w2v = np.concatenate([build_Word_Vector(z, 200) for z in tqdm(map(lambda x: x.words, x_validation))])
val_vecs_w2v = scale(val_vecs_w2v)
# Out:
# 299308it [02:16, 2192.98it/s]
# 74828it [00:33, 2242.84it/s]

# %%
#Sequential keras with 3 layers, 128 input, 200 dimension, sigmoid

model = Sequential()
model.add(Dense(128, activation='relu', input_dim=200))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
#np array implementation
y_train1=np.array(y_train)
y_validation1=np.array(y_validation)

# %%
#fit model for epoch1 and batch size 128
model.fit(train_vecs_w2v, y_train1, epochs=1, batch_size=128, verbose=2)

score = model.evaluate(val_vecs_w2v, y_validation1, verbose=2)
print (score[1])
#WORD2VEC NNN
# Out:
# Train on 299308 samples
# 299308/299308 - 10s - loss: 0.3831 - accuracy: 0.8310
# 74828/1 - 4s - loss: 0.3159 - accuracy: 0.8321
# 0.83205485

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_24 (Dense)             (None, 128)               25728
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_26 (Dense)             (None, 1)                 129
# ...
# Total params: 42,369
# Trainable params: 42,369
# Non-trainable params: 0
# _________________________________________________________________

# %%
import numpy as np
import pandas as pd

# %%
y_validation=np.array(y_validation)

# %%
score = model.evaluate(val_vecs_w2v, y_validation, verbose=2)
# Out:
# 74828/1 - 4s - loss: 0.3159 - accuracy: 0.8321

# %%
from gensim.models import Doc2Vec
import multiprocessing
#DBOW approach while setting dm=0

cores = multiprocessing.cpu_count()
model_dbow = Doc2Vec(dm=0, vector_size=200, negative=5, min_count=2, workers=cores, alpha=0.065, min_alpha=0.065)
model_dbow.build_vocab([x for x in tqdm(all_x_w2v)])
model_dbow.train(utils.shuffle([x for x in tqdm(all_x_w2v)]), total_examples=len(all_x_w2v), epochs=1)

def build_doc_Vector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0.
    for word in tokens:
        try:
            vec += model_dbow[word].reshape((1, size)) * tfidf[word]
            count += 1.
        except KeyError: 
            continue
    if count != 0:
        vec /= count
    return vec

train_vecs_dbow = np.concatenate([build_doc_Vector(z, 200) for z in tqdm(map(lambda x: x.words, x_train))])
train_vecs_dbow = scale(train_vecs_dbow)
val_vecs_dbow = np.concatenate([build_doc_Vector(z, 200) for z in tqdm(map(lambda x: x.words, x_validation))])
val_vecs_dbow = scale(val_vecs_dbow)

model = Sequential()
model.add(Dense(128, activation='relu', input_dim=200))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.fit(train_vecs_dbow, y_train1, epochs=2, batch_size=128, verbose=2)
score = model.evaluate(val_vecs_dbow, y_validation1, batch_size=128, verbose=2)

print (score[1])
# Out:
# ...
# 100%|██████████| 374136/374136 [00:00<00:00, 3361027.30it/s]
#
# ...
# 100%|██████████| 374136/374136 [00:00<00:00, 2936826.02it/s]
#
# 0it [00:00, ?it/s]
# 122it [00:00, 1211.07it/s]
# 244it [00:00, 1125.30it/s]
# 482it [00:00, 1672.96it/s]
# 654it [00:00, 1674.97it/s]
# 854it [00:00, 1788.78it/s]
# 1055it [00:00, 1861.68it/s]
# 1243it [00:00, 1841.32it/s]
# 1428it [00:00, 1826.66it/s]
# 1612it [00:00, 1827.38it/s]
# 1798it [00:01, 1833.28it/s]
# 1982it [00:01, 1746.42it/s]
# 2199it [00:01, 1867.17it/s]
# 2446it [00:01, 2040.47it/s]
# 2652it [00:01, 1889.38it/s]
# 2844it [00:01, 1886.84it/s]
# 3074it [00:01, 1954.87it/s]
# 3284it [00:01, 1995.15it/s]
# 3510it [00:01, 2065.47it/s]
# 3744it [00:01, 2142.96it/s]
# 3960it [00:02, 1946.73it/s]
# 4159it [00:02, 1875.89it/s]
# 4371it [00:02, 1939.15it/s]
# 4568it [00:02, 1942.05it/s]
# 4782it [00:02, 1998.11it/s]
# 4984it [00:02, 1881.28it/s]
# 5193it [00:02, 1936.89it/s]
# 5394it [00:02, 1949.79it/s]
# 5619it [00:02, 2032.25it/s]
# ...

# %%
#DMC approach by dm=1 dm_concat = 1, 200 vector size 
cores = multiprocessing.cpu_count()
model_dmc = Doc2Vec(dm=1, dm_concat=1, vector_size=200, window=2, negative=5, min_count=2, workers=cores, alpha=0.065, min_alpha=0.065)
model_dmc.build_vocab([x for x in tqdm(all_x_w2v)])
model_dmc.train(utils.shuffle([x for x in tqdm(all_x_w2v)]), total_examples=len(all_x_w2v), epochs=1)

def build_doc_Vector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0.
    for word in tokens:
        try:
            vec += model_dmc[word].reshape((1, size)) * tfidf[word]
            count += 1.
        except KeyError: 
            continue
    if count != 0:
        vec /= count
    return vec

  
train_vecs_dmc = np.concatenate([build_doc_Vector(z, 200) for z in tqdm(map(lambda x: x.words, x_train))])
train_vecs_dmc = scale(train_vecs_dmc)


val_vecs_dmc = np.concatenate([build_doc_Vector(z, 200) for z in tqdm(map(lambda x: x.words, x_validation))])
val_vecs_dmc = scale(val_vecs_dmc)

model = Sequential()
model.add(Dense(128, activation='relu', input_dim=200))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(train_vecs_dmc, y_train1, epochs=2, batch_size=128, verbose=2)
score = model.evaluate(val_vecs_dmc, y_validation1,batch_size=128, verbose=2)

print (score[1])
# Out:
#   0%|          | 0/374136 [00:00<?, ?it/s]
#
# 100%|██████████| 374136/374136 [00:00<00:00, 2317607.01it/s]
#
# 100731it [01:08, 1989.24it/s]
#
#   0%|          | 0/374136 [00:00<?, ?it/s]
#
# 100%|██████████| 374136/374136 [00:00<00:00, 3272277.11it/s]
#
#
# 0it [00:00, ?it/s]
#
# 106it [00:00, 1019.29it/s]
#
# 208it [00:00, 1017.74it/s]
#
# 412it [00:00, 1459.56it/s]
#
# 607it [00:00, 1650.06it/s]
#
# 794it [00:00, 1721.22it/s]
#
# 1010it [00:00, 1866.11it/s]
#
# 1197it [00:00, 1859.47it/s]
#
# 1389it [00:00, 1878.29it/s]
#
# 1583it [00:00, 1895.97it/s]
#
# 1773it [00:01, 1876.90it/s]
#
# 1961it [00:01, 1870.20it/s]
#
# 2164it [00:01, 1917.89it/s]
#
# 2403it [00:01, 2059.85it/s]
#
# 2610it [00:01, 1927.51it/s]
#
# 2805it [00:01, 1923.18it/s]
#
# 3050it [00:01, 2073.73it/s]
#
# 3259it [00:01, 2017.99it/s]
#
# 3481it [00:01, 2071.83it/s]
#
# 3690it [00:01, 2068.37it/s]
#
# 3898it [00:02, 2060.01it/s]
#
# 4105it [00:02, 1867.63it/s]
#
# 4296it [00:02, 1847.22it/s]
#
# ...

# %%
#DMM with dm=1 and dm_mean=1 for 200 vector 
cores = multiprocessing.cpu_count()
model_dmm = Doc2Vec(dm=1, dm_mean=1, vector_size=200, window=4, negative=5, min_count=2, workers=cores, alpha=0.065, min_alpha=0.065)
model_dmm.build_vocab([x for x in tqdm(all_x_w2v)])
model_dmm.train(utils.shuffle([x for x in tqdm(all_x_w2v)]), total_examples=len(all_x_w2v), epochs=1)

def build_doc_Vector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0.
    for word in tokens:
        try:
            vec += model_dmm[word].reshape((1, size)) * tfidf[word]
            count += 1.
        except KeyError: 
            continue
    if count != 0:
        vec /= count
    return vec

  
train_vecs_dmm = np.concatenate([build_doc_Vector(z, 200) for z in tqdm(map(lambda x: x.words, x_train))])
train_vecs_dmm = scale(train_vecs_dmm)

val_vecs_dmm = np.concatenate([build_doc_Vector(z, 200) for z in tqdm(map(lambda x: x.words, x_validation))])
val_vecs_dmm = scale(val_vecs_dmm)

model = Sequential()
model.add(Dense(128, activation='relu', input_dim=200))
model.add(Dense(128, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.fit(train_vecs_dmm, y_train1, epochs=2, batch_size=128, verbose=2)
score = model.evaluate(val_vecs_dmm, y_validation1, batch_size=128, verbose=2)
print (score[1])
# Out:
#   0%|          | 0/374136 [00:00<?, ?it/s]
#
#   7%|▋         | 24390/374136 [00:00<00:01, 243863.02it/s]
#
#  13%|█▎        | 48777/374136 [00:00<00:01, 218664.35it/s]
#
#  19%|█▉        | 70814/374136 [00:00<00:01, 216245.32it/s]
#
#  29%|██▊       | 106859/374136 [00:00<00:00, 270339.51it/s]
#
#  36%|███▌      | 134190/374136 [00:00<00:00, 263391.67it/s]
#
#  50%|████▉     | 186841/374136 [00:00<00:00, 347665.52it/s]
#
#  63%|██████▎   | 235094/374136 [00:00<00:00, 383094.33it/s]
#
# 100%|██████████| 374136/374136 [00:00<00:00, 392016.21it/s]
# 0it [14:53, ?it/s]
# 100%|██████████| 374136/374136 [00:00<00:00, 3353499.95it/s]
# 299308it [02:36, 1910.33it/s]
# 74828it [00:40, 1835.45it/s]
# Train on 299308 samples
# Epoch 1/2
# 299308/299308 - 13s - loss: 0.4219 - accuracy: 0.8121
# Epoch 2/2
# 299308/299308 - 12s - loss: 0.3929 - accuracy: 0.8238
# 74828/1 - 2s - loss: 0.3993 - accuracy: 0.8244
# 0.82439727
